# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel(r'D:\FINGERTIPS\PYTHON\PROJECT CLASSROOM\espn cric score (1).xlsx')

# %%
data
# Out:
#    Records for Test Matches Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                       NaN        NaN        NaN        NaN        NaN
# 1          Highest averages        NaN        NaN        NaN        NaN
# 2                    Player       Span        Mat       Inns         NO
# 3          DG Bradman (AUS)  1928-1948         52         80         10
# 4            HC Brook (ENG)  2022-2023         12         20          1
# ..                      ...        ...        ...        ...        ...
# 60         KD Walters (AUS)  1965-1981         74        125         14
# 61        GC Smith (ICC/SA)  2002-2014        117        205         13
# 62        WH Ponsford (AUS)  1924-1934         29         48          4
# 63          SJ McCabe (AUS)  1930-1938         39         62          5
# 64         DR Jardine (ENG)  1928-1934         22         33          6
#
#    Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# ...

# %%
data.columns=data.loc[2]

# %%
data.columns
# Out:
# Index(['Player',   'Span',    'Mat',   'Inns',     'NO',   'Runs',     'HS',
#           'Ave',     'BF',     'SR',    100.0,     50.0,      0.0,     '4s',
#            '6s'],
#       dtype='object', name=2)

# %%
data.columns=['Player',   'Span',    'Mat',   'Inns',     'NO',   'Runs',     'HS',
          'Ave',     'BF',     'SR',    100.0,     50.0,      0.0,     '4s',
           '6s']

# %%
data
# Out:
#                Player       Span  Mat  Inns   NO  Runs   HS    Ave     BF  \
# 0                 NaN        NaN  NaN   NaN  NaN   NaN  NaN    NaN    NaN
# 1    Highest averages        NaN  NaN   NaN  NaN   NaN  NaN    NaN    NaN
# 2              Player       Span  Mat  Inns   NO  Runs   HS    Ave     BF
# 3    DG Bradman (AUS)  1928-1948   52    80   10  6996  334  99.94  9800+
# 4      HC Brook (ENG)  2022-2023   12    20    1  1181  186  62.15   1287
# ..                ...        ...  ...   ...  ...   ...  ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125   14  5357  250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205   13  9265  277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48    4  2122  266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62    5  2748  232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33    6  1296  127     48  2110+
#
#        SR  100.0  50.0   0.0    4s   6s
# ...

# %%
data.drop(data.index[0],axis=0,inplace=True)

# %%
data
# Out:
#                Player       Span  Mat  Inns   NO  Runs    HS    Ave     BF  \
# 1    Highest averages        NaN  NaN   NaN  NaN   NaN   NaN    NaN    NaN
# 2              Player       Span  Mat  Inns   NO  Runs    HS    Ave     BF
# 3    DG Bradman (AUS)  1928-1948   52    80   10  6996   334  99.94  9800+
# 4      HC Brook (ENG)  2022-2023   12    20    1  1181   186  62.15   1287
# 5      AC Voges (AUS)  2015-2016   20    31    7  1485  269*  61.87   2667
# ..                ...        ...  ...   ...  ...   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125   14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205   13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48    4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62    5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33    6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s   6s
# ...

# %%
data.drop(data.index[0],axis=0,inplace=True)

# %%
data
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 2              Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF
# 3    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 4      HC Brook (ENG)  2022-2023   12    20   1  1181   186  62.15   1287
# 5      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 6     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s  6s
# 2      SR  100.0  50.0   0.0    4s  6s
# ...

# %%
data.drop(data.index[0],axis=0,inplace=True)

# %%
data
# Out:
#                Player       Span  Mat Inns  NO  Runs    HS    Ave     BF  \
# 3    DG Bradman (AUS)  1928-1948   52   80  10  6996   334  99.94  9800+
# 4      HC Brook (ENG)  2022-2023   12   20   1  1181   186  62.15   1287
# 5      AC Voges (AUS)  2015-2016   20   31   7  1485  269*  61.87   2667
# 6     RG Pollock (SA)  1963-1970   23   41   4  2256   274  60.97  1707+
# 7     GA Headley (WI)  1930-1954   22   40   4  2190  270*  60.83   416+
# ..                ...        ...  ...  ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74  125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117  205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29   48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39   62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22   33   6  1296   127     48  2110+
#
#        SR  100.0  50.0   0.0    4s  6s
# 3    58.6   29.0  13.0   7.0  626+   6
# ...

# %%
data[data['BF']=='-'].index
# Out:
# Index([11, 17, 57], dtype='int64')

# %%
data.drop(data[data['BF']=='-'].index,inplace=True)

# %%
data
# Out:
#                       Player       Span   Mat Inns  NO   Runs    HS    Ave  \
# 3           DG Bradman (AUS)  1928-1948    52   80  10   6996   334  99.94
# 4             HC Brook (ENG)  2022-2023    12   20   1   1181   186  62.15
# 5             AC Voges (AUS)  2015-2016    20   31   7   1485  269*  61.87
# 6            RG Pollock (SA)  1963-1970    23   41   4   2256   274  60.97
# 7            GA Headley (WI)  1930-1954    22   40   4   2190  270*  60.83
# 8          H Sutcliffe (ENG)  1924-1935    54   84   9   4555   194  60.73
# 9            E Paynter (ENG)  1931-1939    20   31   5   1540   243  59.23
# 10       KF Barrington (ENG)  1955-1968    82  131  15   6806   256  58.67
# 12          WR Hammond (ENG)  1927-1947    85  140  16   7249  336*  58.45
# 13            GS Sobers (WI)  1954-1974    93  160  21   8032  365*  57.78
# 14        KC Sangakkara (SL)  2000-2015   134  233  17  12400   319   57.4
# ...

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#     index                    Player       Span   Mat Inns  NO   Runs    HS  \
# 0       3          DG Bradman (AUS)  1928-1948    52   80  10   6996   334
# 1       4            HC Brook (ENG)  2022-2023    12   20   1   1181   186
# 2       5            AC Voges (AUS)  2015-2016    20   31   7   1485  269*
# 3       6           RG Pollock (SA)  1963-1970    23   41   4   2256   274
# 4       7           GA Headley (WI)  1930-1954    22   40   4   2190  270*
# 5       8         H Sutcliffe (ENG)  1924-1935    54   84   9   4555   194
# 6       9           E Paynter (ENG)  1931-1939    20   31   5   1540   243
# 7      10       KF Barrington (ENG)  1955-1968    82  131  15   6806   256
# 8      12          WR Hammond (ENG)  1927-1947    85  140  16   7249  336*
# 9      13            GS Sobers (WI)  1954-1974    93  160  21   8032  365*
# 10     14        KC Sangakkara (SL)  2000-2015   134  233  17  12400   319
# ...

# %%
data.drop('index',axis=1,inplace=True)

# %%
data
# Out:
#                       Player       Span   Mat Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948    52   80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023    12   20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016    20   31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970    23   41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954    22   40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935    54   84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939    20   31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968    82  131  15   6806   256  58.67
# 8           WR Hammond (ENG)  1927-1947    85  140  16   7249  336*  58.45
# 9             GS Sobers (WI)  1954-1974    93  160  21   8032  365*  57.78
# 10        KC Sangakkara (SL)  2000-2015   134  233  17  12400   319   57.4
# ...

# %%
data['Span'].str.split('-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2023]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
# 5     [1924, 1935]
# 6     [1931, 1939]
# 7     [1955, 1968]
# 8     [1927, 1947]
# 9     [1954, 1974]
# 10    [2000, 2015]
# 11    [2010, 2024]
# 12    [1908, 1930]
# 13    [1937, 1955]
# 14    [1995, 2013]
# 15    [1921, 1929]
# 16    [2010, 2024]
# 17    [1968, 1973]
# 18    [1993, 1995]
# 19    [1970, 1984]
# 20    [1935, 1951]
# 21    [1989, 2013]
# 22    [1990, 2006]
# 23    [1976, 1993]
# 24    [1996, 2012]
# 25    [1998, 2010]
# 26    [2000, 2017]
# 27    [1995, 2012]
# 28    [1920, 1929]
# 29    [1992, 2002]
# 30    [2005, 2013]
# 31    [1994, 2015]
# 32    [1971, 1987]
# 33    [1985, 2004]
# 34    [1994, 2009]
# 35    [2004, 2018]
# 36    [1978, 1994]
# 37    [2019, 2024]
# 38    [1974, 1991]
# 39    [1937, 1957]
# 40    [1997, 2014]
# 41    [2012, 2024]
# 42    [1992, 2007]
# 43    [2018, 2024]
# 44    [1948, 1963]
# 45    [1911, 1928]
# 46    [2001, 2013]
# ...

# %%
data['Start_Year']=data['Span'].str.split('-').str[0]
data['End_Year']=data['Span'].str.split('-').str[1]

# %%
data
# Out:
#                       Player       Span   Mat Inns  NO   Runs    HS    Ave  \
# 0           DG Bradman (AUS)  1928-1948    52   80  10   6996   334  99.94
# 1             HC Brook (ENG)  2022-2023    12   20   1   1181   186  62.15
# 2             AC Voges (AUS)  2015-2016    20   31   7   1485  269*  61.87
# 3            RG Pollock (SA)  1963-1970    23   41   4   2256   274  60.97
# 4            GA Headley (WI)  1930-1954    22   40   4   2190  270*  60.83
# 5          H Sutcliffe (ENG)  1924-1935    54   84   9   4555   194  60.73
# 6            E Paynter (ENG)  1931-1939    20   31   5   1540   243  59.23
# 7        KF Barrington (ENG)  1955-1968    82  131  15   6806   256  58.67
# 8           WR Hammond (ENG)  1927-1947    85  140  16   7249  336*  58.45
# 9             GS Sobers (WI)  1954-1974    93  160  21   8032  365*  57.78
# 10        KC Sangakkara (SL)  2000-2015   134  233  17  12400   319   57.4
# ...

# %%
data.drop('Span',axis=1,inplace=True)

# %%
data
# Out:
#                       Player   Mat Inns  NO   Runs    HS    Ave      BF  \
# 0           DG Bradman (AUS)    52   80  10   6996   334  99.94   9800+
# 1             HC Brook (ENG)    12   20   1   1181   186  62.15    1287
# 2             AC Voges (AUS)    20   31   7   1485  269*  61.87    2667
# 3            RG Pollock (SA)    23   41   4   2256   274  60.97   1707+
# 4            GA Headley (WI)    22   40   4   2190  270*  60.83    416+
# 5          H Sutcliffe (ENG)    54   84   9   4555   194  60.73   6558+
# 6            E Paynter (ENG)    20   31   5   1540   243  59.23   1288+
# 7        KF Barrington (ENG)    82  131  15   6806   256  58.67   4957+
# 8           WR Hammond (ENG)    85  140  16   7249  336*  58.45   7491+
# 9             GS Sobers (WI)    93  160  21   8032  365*  57.78   4063+
# 10        KC Sangakkara (SL)   134  233  17  12400   319   57.4   22882
# 11           SPD Smith (AUS)  109*  195  25   9685   239  56.97   18100
# ...

# %%
data['Player'].str.split(' ')
# Out:
# 0            [DG, Bradman, (AUS)]
# 1              [HC, Brook, (ENG)]
# 2              [AC, Voges, (AUS)]
# 3             [RG, Pollock, (SA)]
# 4             [GA, Headley, (WI)]
# 5           [H, Sutcliffe, (ENG)]
# 6             [E, Paynter, (ENG)]
# 7         [KF, Barrington, (ENG)]
# 8            [WR, Hammond, (ENG)]
# 9              [GS, Sobers, (WI)]
# 10         [KC, Sangakkara, (SL)]
# 11            [SPD, Smith, (AUS)]
# 12             [JB, Hobbs, (ENG)]
# 13             [L, Hutton, (ENG)]
# 14         [JH, Kallis, (ICC/SA)]
# 15         [GE, Tyldesley, (ENG)]
# 16         [KS, Williamson, (NZ)]
# 17              [CA, Davis, (WI)]
# 18            [VG, Kambli, (IND)]
# 19          [GS, Chappell, (AUS)]
# 20             [AD, Nourse, (SA)]
# 21         [SR, Tendulkar, (IND)]
# 22           [BC, Lara, (ICC/WI)]
# 23        [Javed, Miandad, (PAK)]
# 24         [R, Dravid, (ICC/IND)]
# 25      [Mohammad, Yousuf, (PAK)]
# 26          [Younis, Khan, (PAK)]
# ...

# %%
data['Country']=data['Player'].str.split(' ').str[2].replace('[()]','',regex=True)

# %%
data
# Out:
#                       Player   Mat Inns  NO   Runs    HS    Ave      BF  \
# 0           DG Bradman (AUS)    52   80  10   6996   334  99.94   9800+
# 1             HC Brook (ENG)    12   20   1   1181   186  62.15    1287
# 2             AC Voges (AUS)    20   31   7   1485  269*  61.87    2667
# 3            RG Pollock (SA)    23   41   4   2256   274  60.97   1707+
# 4            GA Headley (WI)    22   40   4   2190  270*  60.83    416+
# 5          H Sutcliffe (ENG)    54   84   9   4555   194  60.73   6558+
# 6            E Paynter (ENG)    20   31   5   1540   243  59.23   1288+
# 7        KF Barrington (ENG)    82  131  15   6806   256  58.67   4957+
# 8           WR Hammond (ENG)    85  140  16   7249  336*  58.45   7491+
# 9             GS Sobers (WI)    93  160  21   8032  365*  57.78   4063+
# 10        KC Sangakkara (SL)   134  233  17  12400   319   57.4   22882
# 11           SPD Smith (AUS)  109*  195  25   9685   239  56.97   18100
# ...

# %%
data['Player']=data['Player'].str.split('[(]').str[0]

# %%
data
# Out:
#                Player   Mat Inns  NO   Runs    HS    Ave      BF     SR  \
# 0         DG Bradman     52   80  10   6996   334  99.94   9800+   58.6
# 1           HC Brook     12   20   1   1181   186  62.15    1287  91.76
# 2           AC Voges     20   31   7   1485  269*  61.87    2667  55.68
# 3         RG Pollock     23   41   4   2256   274  60.97   1707+  54.48
# 4         GA Headley     22   40   4   2190  270*  60.83    416+     56
# 5        H Sutcliffe     54   84   9   4555   194  60.73   6558+  34.59
# 6          E Paynter     20   31   5   1540   243  59.23   1288+  45.88
# 7      KF Barrington     82  131  15   6806   256  58.67   4957+  42.42
# 8         WR Hammond     85  140  16   7249  336*  58.45   7491+  38.07
# 9          GS Sobers     93  160  21   8032  365*  57.78   4063+  53.58
# 10     KC Sangakkara    134  233  17  12400   319   57.4   22882  54.19
# 11         SPD Smith   109*  195  25   9685   239  56.97   18100   53.5
# ...

# %%
data.columns
# Out:
# Index([    'Player',        'Mat',       'Inns',         'NO',       'Runs',
#                'HS',        'Ave',         'BF',         'SR',        100.0,
#                50.0,          0.0,         '4s',         '6s', 'Start_Year',
#          'End_Year',    'Country'],
#       dtype='object')

# %%
data[['Mat',       'Inns',         'NO',       'Runs',
               'HS',        'Ave',         'BF',         'SR',        100.0,
               50.0,          0.0,         '4s',         '6s']]   =   data[['Mat',       'Inns',         'NO',       'Runs',
               'HS',        'Ave',         'BF',         'SR',        100.0,
               50.0,          0.0,         '4s',         '6s']].replace('[*+]','',regex=True)

# %%
data
# Out:
#                Player  Mat  Inns  NO   Runs   HS    Ave     BF     SR  100.0  \
# 0         DG Bradman    52    80  10   6996  334  99.94   9800  58.60   29.0
# 1           HC Brook    12    20   1   1181  186  62.15   1287  91.76    4.0
# 2           AC Voges    20    31   7   1485  269  61.87   2667  55.68    5.0
# 3         RG Pollock    23    41   4   2256  274  60.97   1707  54.48    7.0
# 4         GA Headley    22    40   4   2190  270  60.83    416  56.00   10.0
# 5        H Sutcliffe    54    84   9   4555  194  60.73   6558  34.59   16.0
# 6          E Paynter    20    31   5   1540  243  59.23   1288  45.88    4.0
# 7      KF Barrington    82   131  15   6806  256  58.67   4957  42.42   20.0
# 8         WR Hammond    85   140  16   7249  336  58.45   7491  38.07   22.0
# 9          GS Sobers    93   160  21   8032  365  57.78   4063  53.58   26.0
# 10     KC Sangakkara   134   233  17  12400  319  57.40  22882  54.19   38.0
# ...

# %%
data['Country'].replace('Villiers','SA',inplace=True)

# %%
data
# Out:
#                Player  Mat  Inns  NO   Runs   HS    Ave     BF     SR  100.0  \
# 0         DG Bradman    52    80  10   6996  334  99.94   9800  58.60   29.0
# 1           HC Brook    12    20   1   1181  186  62.15   1287  91.76    4.0
# 2           AC Voges    20    31   7   1485  269  61.87   2667  55.68    5.0
# 3         RG Pollock    23    41   4   2256  274  60.97   1707  54.48    7.0
# 4         GA Headley    22    40   4   2190  270  60.83    416  56.00   10.0
# 5        H Sutcliffe    54    84   9   4555  194  60.73   6558  34.59   16.0
# 6          E Paynter    20    31   5   1540  243  59.23   1288  45.88    4.0
# 7      KF Barrington    82   131  15   6806  256  58.67   4957  42.42   20.0
# 8         WR Hammond    85   140  16   7249  336  58.45   7491  38.07   22.0
# 9          GS Sobers    93   160  21   8032  365  57.78   4063  53.58   26.0
# 10     KC Sangakkara   134   233  17  12400  319  57.40  22882  54.19   38.0
# ...

# %%
data['Country'][35]
# Out:
# 'SA'

# %%
data
# Out:
#                Player  Mat  Inns  NO   Runs   HS    Ave     BF     SR  100.0  \
# 0         DG Bradman    52    80  10   6996  334  99.94   9800  58.60   29.0
# 1           HC Brook    12    20   1   1181  186  62.15   1287  91.76    4.0
# 2           AC Voges    20    31   7   1485  269  61.87   2667  55.68    5.0
# 3         RG Pollock    23    41   4   2256  274  60.97   1707  54.48    7.0
# 4         GA Headley    22    40   4   2190  270  60.83    416  56.00   10.0
# 5        H Sutcliffe    54    84   9   4555  194  60.73   6558  34.59   16.0
# 6          E Paynter    20    31   5   1540  243  59.23   1288  45.88    4.0
# 7      KF Barrington    82   131  15   6806  256  58.67   4957  42.42   20.0
# 8         WR Hammond    85   140  16   7249  336  58.45   7491  38.07   22.0
# 9          GS Sobers    93   160  21   8032  365  57.78   4063  53.58   26.0
# 10     KC Sangakkara   134   233  17  12400  319  57.40  22882  54.19   38.0
# ...

# %%
data.isnull().sum()
# Out:
# Player        0
# Mat           0
# Inns          0
# NO            0
# Runs          0
# HS            0
# Ave           0
# BF            0
# SR            0
# 100.0         0
# 50.0          0
# 0.0           0
# 4s            0
# 6s            0
# Start_Year    0
# End_Year      0
# Country       1
# dtype: int64

# %%
data.fillna('Pak',inplace=True)

# %%
data
# Out:
#                Player  Mat  Inns  NO   Runs   HS    Ave     BF     SR  100.0  \
# 0         DG Bradman    52    80  10   6996  334  99.94   9800  58.60   29.0
# 1           HC Brook    12    20   1   1181  186  62.15   1287  91.76    4.0
# 2           AC Voges    20    31   7   1485  269  61.87   2667  55.68    5.0
# 3         RG Pollock    23    41   4   2256  274  60.97   1707  54.48    7.0
# 4         GA Headley    22    40   4   2190  270  60.83    416  56.00   10.0
# 5        H Sutcliffe    54    84   9   4555  194  60.73   6558  34.59   16.0
# 6          E Paynter    20    31   5   1540  243  59.23   1288  45.88    4.0
# 7      KF Barrington    82   131  15   6806  256  58.67   4957  42.42   20.0
# 8         WR Hammond    85   140  16   7249  336  58.45   7491  38.07   22.0
# 9          GS Sobers    93   160  21   8032  365  57.78   4063  53.58   26.0
# 10     KC Sangakkara   134   233  17  12400  319  57.40  22882  54.19   38.0
# ...

# %%
data.isnull().sum()
# Out:
# Player        0
# Mat           0
# Inns          0
# NO            0
# Runs          0
# HS            0
# Ave           0
# BF            0
# SR            0
# 100.0         0
# 50.0          0
# 0.0           0
# 4s            0
# 6s            0
# Start_Year    0
# End_Year      0
# Country       0
# dtype: int64

# %%
data.to_csv('D:\FINGERTIPS\PYTHON\PROJECT CLASSROOM\ESPN_Cleaned_Data.csv', index=False)
